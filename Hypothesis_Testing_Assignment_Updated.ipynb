# %% [markdown]
# <a href="https://colab.research.google.com/github/nkcwealth/Advanced-Mathematics/blob/main/Hypothesis_Testing_Assignment_Updated.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <center> **Hypothesis Testing**

# %% [markdown]
# ### Null & Alternate Hypothesis

# %% [markdown]
# **Question 1:**
# Suppose you are conducting a study to determine whether a new drug is effective in reducing blood pressure. Define the null hypothesis (H0) and the alternate hypothesis (H1) for this study. Explain the significance of each hypothesis in the context of your research.
#
# **Question 2:**
# You are working with a manufacturing company that claims its new manufacturing process can produce car batteries with a longer lifespan than the current process. Formulate the null and alternate hypotheses for this scenario. Additionally, explain why it's essential to have clear and well-defined hypotheses before conducting hypothesis testing.
#
# **Question 3:**
# A fast-food restaurant chain is concerned that the average delivery time for online orders has increased in recent months, potentially affecting customer satisfaction. Create the null and alternate hypotheses for testing whether there has been a significant increase in delivery times.
#
# *These questions will help you to practice defining and understanding null and alternate hypotheses in various real-world scenarios.*

# %%
# !pip install numpy scipy
# Out:
# Requirement already satisfied: numpy in c:\users\ddvad\appdata\local\programs\python\python313\lib\site-packages (2.2.4)
# Collecting scipy
#   Downloading scipy-1.15.2-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Downloading scipy-1.15.2-cp313-cp313-win_amd64.whl (41.0 MB)
#    ---------------------------------------- 0.0/41.0 MB ? eta -:--:--
#    - -------------------------------------- 1.0/41.0 MB 10.0 MB/s eta 0:00:04
#    - -------------------------------------- 1.6/41.0 MB 6.2 MB/s eta 0:00:07
#    --- ------------------------------------ 3.1/41.0 MB 5.3 MB/s eta 0:00:08
#    ---- ----------------------------------- 4.2/41.0 MB 5.0 MB/s eta 0:00:08
#    ---- ----------------------------------- 5.0/41.0 MB 4.9 MB/s eta 0:00:08
#    ----- ---------------------------------- 5.8/41.0 MB 4.8 MB/s eta 0:00:08
#    ------ --------------------------------- 6.8/41.0 MB 4.7 MB/s eta 0:00:08
#    ------- -------------------------------- 7.6/41.0 MB 4.6 MB/s eta 0:00:08
#    -------- ------------------------------- 8.7/41.0 MB 4.6 MB/s eta 0:00:08
#    --------- ------------------------------ 9.7/41.0 MB 4.6 MB/s eta 0:00:07
#    ---------- ----------------------------- 10.7/41.0 MB 4.7 MB/s eta 0:00:07
#    ----------- ---------------------------- 12.1/41.0 MB 4.9 MB/s eta 0:00:06
#    ------------ --------------------------- 12.8/41.0 MB 4.8 MB/s eta 0:00:06
#    -------------- ------------------------- 14.4/41.0 MB 4.9 MB/s eta 0:00:06
#    --------------- ------------------------ 15.5/41.0 MB 4.9 MB/s eta 0:00:06
#    --------------- ------------------------ 16.3/41.0 MB 4.9 MB/s eta 0:00:06
#    ---------------- ----------------------- 16.8/41.0 MB 4.7 MB/s eta 0:00:06
#    ----------------- ---------------------- 17.6/41.0 MB 4.6 MB/s eta 0:00:06
#    ----------------- ---------------------- 18.4/41.0 MB 4.6 MB/s eta 0:00:05
#    ------------------ --------------------- 19.1/41.0 MB 4.6 MB/s eta 0:00:05
#    ------------------- -------------------- 20.2/41.0 MB 4.6 MB/s eta 0:00:05
#    -------------------- ------------------- 21.0/41.0 MB 4.5 MB/s eta 0:00:05
#    --------------------- ------------------ 22.0/41.0 MB 4.5 MB/s eta 0:00:05
#    ---------------------- ----------------- 22.8/41.0 MB 4.5 MB/s eta 0:00:05
#    ----------------------- ---------------- 23.6/41.0 MB 4.5 MB/s eta 0:00:04
#    ------------------------ --------------- 24.9/41.0 MB 4.6 MB/s eta 0:00:04
#    ------------------------- -------------- 26.0/41.0 MB 4.6 MB/s eta 0:00:04
#    -------------------------- ------------- 27.0/41.0 MB 4.6 MB/s eta 0:00:04
#    --------------------------- ------------ 28.0/41.0 MB 4.6 MB/s eta 0:00:03
#    ---------------------------- ----------- 29.1/41.0 MB 4.6 MB/s eta 0:00:03
#    ----------------------------- ---------- 30.1/41.0 MB 4.7 MB/s eta 0:00:03
#    ------------------------------ --------- 31.2/41.0 MB 4.7 MB/s eta 0:00:03
#    ------------------------------- -------- 32.0/41.0 MB 4.7 MB/s eta 0:00:02
#    -------------------------------- ------- 33.3/41.0 MB 4.7 MB/s eta 0:00:02
#    --------------------------------- ------ 34.3/41.0 MB 4.7 MB/s eta 0:00:02
#    ---------------------------------- ----- 35.7/41.0 MB 4.7 MB/s eta 0:00:02
#    ----------------------------------- ---- 36.7/41.0 MB 4.7 MB/s eta 0:00:01
#    ------------------------------------ --- 37.5/41.0 MB 4.7 MB/s eta 0:00:01
#    ------------------------------------- -- 38.8/41.0 MB 4.7 MB/s eta 0:00:01
#    -------------------------------------- - 39.3/41.0 MB 4.7 MB/s eta 0:00:01
#    ---------------------------------------  40.4/41.0 MB 4.7 MB/s eta 0:00:01
#    ---------------------------------------  40.9/41.0 MB 4.7 MB/s eta 0:00:01
#    ---------------------------------------- 41.0/41.0 MB 4.5 MB/s eta 0:00:00
# Installing collected packages: scipy
# Successfully installed scipy-1.15.2

# %%
import scipy.stats as stats

# Sample data (example)
sample_mean = 78  # average score of 30 students
population_mean = 75  # national average
population_std = 10  # known population standard deviation
sample_size = 30

# Z-score formula
z_score = (sample_mean - population_mean) / (population_std / (sample_size ** 0.5))
p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))  # two-tailed test

print(f"Z-Score: {z_score:.2f}")
print(f"P-Value: {p_value:.4f}")
if p_value < 0.05:
    print("Reject the null hypothesis.")
else:
    print("Fail to reject the null hypothesis.")
# Out:
# Z-Score: 1.64
# P-Value: 0.1003
# Fail to reject the null hypothesis.

# %%
import numpy as np
import scipy.stats as stats

# Example data (cholesterol levels reduction)
new_drug = np.random.normal(loc=25, scale=5, size=50)
current_med = np.random.normal(loc=22, scale=5, size=50)

mean_diff = np.mean(new_drug) - np.mean(current_med)
pooled_std = np.sqrt( (np.std(new_drug, ddof=1) ** 2 / 50) + (np.std(current_med, ddof=1) ** 2 / 50) )
z_score = mean_diff / pooled_std
p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))

print(f"Z-Score: {z_score:.2f}")
print(f"P-Value: {p_value:.4f}")
if p_value < 0.05:
    print("Reject the null hypothesis.")
else:
    print("Fail to reject the null hypothesis.")
# Out:
# Z-Score: 0.97
# P-Value: 0.3330
# Fail to reject the null hypothesis.

# %% [markdown]
# ### Rejection Region Approach & Z-test Implementation

# %% [markdown]
# import numpy as np
# import scipy.stats as stats
#
# # Example data for mileage
# sample_mean = 245  # observed sample mean mileage
# population_mean = 250  # claimed by manufacturer
# population_std = 12  # assumed known
# sample_size = 36
#
# z_score = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))
# p_value = stats.norm.cdf(z_score)  # one-tailed test (less than)
#
# print(f"Z-Score: {z_score:.2f}")
# print(f"P-Value: {p_value:.4f}")
# if p_value < 0.01:
#     print("Reject the null hypothesis.")
# else:
#     print("Fail to reject the null hypothesis.")

# %%
import numpy as np
import scipy.stats as stats

# Sample data
masters = np.random.normal(75000, 8000, 100)
bachelors = np.random.normal(70000, 7500, 100)

mean_diff = np.mean(masters) - np.mean(bachelors)
pooled_std = np.sqrt((np.var(masters, ddof=1) / 100) + (np.var(bachelors, ddof=1) / 100))
z_score = mean_diff / pooled_std
p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))

print(f"Z-Score: {z_score:.2f}")
print(f"P-Value: {p_value:.4f}")
if p_value < 0.05:
    print("Reject the null hypothesis.")
else:
    print("Fail to reject the null hypothesis.")
# Out:
# Z-Score: 3.59
# P-Value: 0.0003
# Reject the null hypothesis.

# %% [markdown]
# ### Type 1 & Type 2 Errors

# %% [markdown]
# **Case Study 1: Medical Testing**
#
# **Scenario**:
# A medical company has developed a new diagnostic test for a rare disease. The test is highly sensitive, meaning it rarely misses true cases of the disease (low Type II error rate). However, the company is concerned about the Type I error rate, as false positives can lead to unnecessary stress and further testing for patients.
#
# **Assignment:**
#
# 1. Describe the potential consequences of a Type I error in this medical testing scenario.
# 2. Explain the potential consequences of a Type II error.
# 3. Discuss the trade-off between Type I and Type II errors in medical testing and how it influences the decision on test thresholds.

# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.10.1-cp313-cp313-win_amd64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.1-cp313-cp313-win_amd64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.57.0-cp313-cp313-win_amd64.whl.metadata (104 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.8-cp313-cp313-win_amd64.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.23 in c:\users\ddvad\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (2.2.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\ddvad\appdata\roaming\python\python313\site-packages (from matplotlib) (24.2)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-11.2.1-cp313-cp313-win_amd64.whl.metadata (9.1 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ddvad\appdata\roaming\python\python313\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\ddvad\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.1-cp313-cp313-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ----- ---------------------------------- 1.0/8.1 MB 5.0 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.4/8.1 MB 5.5 MB/s eta 0:00:02
#    ---------------- ----------------------- 3.4/8.1 MB 5.5 MB/s eta 0:00:01
#    -------------------- ------------------- 4.2/8.1 MB 4.9 MB/s eta 0:00:01
#    ------------------------ --------------- 5.0/8.1 MB 4.6 MB/s eta 0:00:01
#    ---------------------------- ----------- 5.8/8.1 MB 4.5 MB/s eta 0:00:01
#    -------------------------------- ------- 6.6/8.1 MB 4.4 MB/s eta 0:00:01
#    ------------------------------------ --- 7.3/8.1 MB 4.3 MB/s eta 0:00:01
#    ---------------------------------------  7.9/8.1 MB 4.3 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 4.1 MB/s eta 0:00:00
# Downloading contourpy-1.3.1-cp313-cp313-win_amd64.whl (220 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.57.0-cp313-cp313-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    -------------- ------------------------- 0.8/2.2 MB 4.6 MB/s eta 0:00:01
#    --------------------------------- ------ 1.8/2.2 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 4.0 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.8-cp313-cp313-win_amd64.whl (71 kB)
# Downloading pillow-11.2.1-cp313-cp313-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ----------- ---------------------------- 0.8/2.7 MB 5.1 MB/s eta 0:00:01
#    --------------------------- ------------ 1.8/2.7 MB 5.0 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 5.1 MB/s eta 0:00:00
# Downloading pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.1 cycler-0.12.1 fonttools-4.57.0 kiwisolver-1.4.8 matplotlib-3.10.1 pillow-11.2.1 pyparsing-3.2.3

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Simulate distributions for healthy and diseased individuals
x = np.linspace(0, 10, 1000)
mean_healthy = 5
std_healthy = 1
mean_disease = 7
std_disease = 1

# Probability distributions
healthy_dist = norm.pdf(x, mean_healthy, std_healthy)
disease_dist = norm.pdf(x, mean_disease, std_disease)

# Decision threshold
threshold = 6

plt.figure(figsize=(10, 6))
plt.plot(x, healthy_dist, label="Healthy Population", color='blue')
plt.plot(x, disease_dist, label="Diseased Population", color='red')
plt.axvline(threshold, color='black', linestyle='--', label='Decision Threshold')

# Shaded regions
plt.fill_between(x, 0, healthy_dist, where=(x > threshold), color='blue', alpha=0.3, label='Type I Error (False Positive)')
plt.fill_between(x, 0, disease_dist, where=(x < threshold), color='red', alpha=0.3, label='Type II Error (False Negative)')

plt.title("Type I vs Type II Error in Medical Testing")
plt.xlabel("Test Score")
plt.ylabel("Probability Density")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# **Case Study 2: Criminal Justice System**
#
# **Scenario:**
# In a criminal trial, the prosecution aims to convict a defendant based on evidence. The consequences of a wrongful conviction (Type I error) are severe, but so are the consequences of letting a guilty person go free (Type II error).
#
# **Assignment:**
#
# 1. Describe a situation in the criminal justice system where a Type I error can occur and its implications.
# 2. Provide an example of a situation where a Type II error can occur and its potential consequences.
# 3. Discuss the challenges and ethical considerations in finding a balance between minimizing Type I and Type II errors in criminal trials.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Simulate distributions for innocent and guilty defendants
x = np.linspace(-4, 8, 1000)
mean_innocent = 0
std_innocent = 1
mean_guilty = 4
std_guilty = 1

innocent_dist = norm.pdf(x, mean_innocent, std_innocent)
guilty_dist = norm.pdf(x, mean_guilty, std_guilty)

# Decision threshold for "guilty verdict"
threshold = 2.5

plt.figure(figsize=(10, 6))
plt.plot(x, innocent_dist, label="Innocent Defendants", color='blue')
plt.plot(x, guilty_dist, label="Guilty Defendants", color='red')
plt.axvline(threshold, color='black', linestyle='--', label='Guilty Verdict Threshold')

# Highlight error areas
plt.fill_between(x, 0, innocent_dist, where=(x > threshold), color='blue', alpha=0.3, label='Type I Error (Wrongful Conviction)')
plt.fill_between(x, 0, guilty_dist, where=(x < threshold), color='red', alpha=0.3, label='Type II Error (Guilty Acquitted)')

plt.title("Type I vs Type II Errors in Criminal Justice")
plt.xlabel("Evidence Strength")
plt.ylabel("Probability Density")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# **Case Study 3: Product Quality Control**
#
# **Scenario**:
# A manufacturing company uses a quality control process to ensure that its products meet specific standards. Rejecting a good product (Type I error) can be costly, while accepting a defective product (Type II error) can harm the company's reputation.
#
# **Assignment**:
#
# 1. Describe a scenario in product quality control where a Type I error may occur and its financial implications.
# 2. Provide an example of a situation where a Type II error can occur and its potential impact on the company's reputation.
# 3. Discuss strategies that the company can implement to strike a balance between minimizing Type I and Type II errors in its quality control process.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Simulate distributions for good and defective products based on measurements
x = np.linspace(80, 120, 1000)
mean_good = 100
std_good = 3
mean_defective = 105  # Defective products tend to be slightly heavier
std_defective = 3

good_dist = norm.pdf(x, mean_good, std_good)
defective_dist = norm.pdf(x, mean_defective, std_defective)

# Quality threshold
threshold = 103  # anything above this is rejected

plt.figure(figsize=(10, 6))
plt.plot(x, good_dist, label="Good Products", color='green')
plt.plot(x, defective_dist, label="Defective Products", color='orange')
plt.axvline(threshold, color='black', linestyle='--', label='Rejection Threshold')

# Highlight error zones
plt.fill_between(x, 0, good_dist, where=(x > threshold), color='green', alpha=0.3, label='Type I Error (Rejecting Good Product)')
plt.fill_between(x, 0, defective_dist, where=(x < threshold), color='orange', alpha=0.3, label='Type II Error (Accepting Defective Product)')

plt.title("Type I vs Type II Errors in Product Quality Control")
plt.xlabel("Measurement (e.g., weight)")
plt.ylabel("Probability Density")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### P-value Approach & T-test Implementation

# %% [markdown]
# **Case Study 1: Education**
#
# **Scenario**:
# A school district is implementing a new teaching method aimed at improving students' math scores. They want to know if the new method is effective. A random sample of 30 students who received the new instruction method is compared to a sample of 30 students who received the traditional method. The district wants to use a t-test to analyze the data.
#
# **Assignment:**
#
# 1. Formulate the null and alternate hypotheses for this study.
# 2. Perform a t-test using the collected data and calculate the t-statistic.
# 3. Calculate the P-value and interpret its significance.
# Based on the P-value and a significance level of 0.05, make a decision regarding the null hypothesis.

# %%
import numpy as np
import scipy.stats as stats

# Simulated math scores
np.random.seed(42)  # for reproducibility
new_method_scores = np.random.normal(loc=78, scale=10, size=30)
traditional_method_scores = np.random.normal(loc=74, scale=10, size=30)

# Hypotheses:
# H0: There is no difference in average scores between the two methods.
# H1: There is a significant difference in average scores.

# Perform independent two-sample t-test
t_stat, p_value = stats.ttest_ind(new_method_scores, traditional_method_scores)

print(f"New Method Mean Score: {np.mean(new_method_scores):.2f}")
print(f"Traditional Method Mean Score: {np.mean(traditional_method_scores):.2f}")
print(f"T-Statistic: {t_stat:.2f}")
print(f"P-Value: {p_value:.4f}")

# Interpret result
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: The new teaching method has a significant effect.")
else:
    print("Fail to reject the null hypothesis: No significant difference found.")
# Out:
# New Method Mean Score: 76.12
# Traditional Method Mean Score: 72.79
# T-Statistic: 1.41
# P-Value: 0.1643
# Fail to reject the null hypothesis: No significant difference found.

# %% [markdown]
# **Case Study 2: Baseball Player Performance**
#
# **Scenario**:
# You are a data analyst for a professional baseball team. The team's management wants to assess whether a new training program has led to a significant improvement in the batting averages of their players. You have collected batting average data for two groups of players: one group who underwent the new training program (Group A) and another group who did not (Group B).
#
# **Data**:
#
# **Group A** (New Training Program):
#
# Sample Size: 25 players,
# Mean Batting Average: 0.285,
# Sample Standard Deviation: 0.040.
#
# **Group B** (No Training Program):
#
# Sample Size: 30 players,
# Mean Batting Average: 0.270,
# Sample Standard Deviation: 0.045.
#
# **Assignment:**
#
# 1. Formulate the null and alternate hypotheses to test whether the new training program has led to a significant improvement in batting averages.
# 2. Conduct a two-sample t-test using the provided data. Calculate the t-statistic.
# 3. Calculate the degrees of freedom for the test.
# 4. Calculate the p-value associated with the test.
# 5. Interpret the results and make a recommendation to the team's management based on the p-value approach.

# %%
import scipy.stats as stats
import numpy as np

# Sample data
n1, mean1, std1 = 25, 0.285, 0.040  # Group A (New Training)
n2, mean2, std2 = 30, 0.270, 0.045  # Group B (No Training)

# Hypotheses:
# H0: mean1 = mean2 (no improvement)
# H1: mean1 > mean2 (improvement with new training)

# Calculate t-statistic
se = np.sqrt((std1**2 / n1) + (std2**2 / n2))
t_stat = (mean1 - mean2) / se

# Calculate degrees of freedom using Welch's formula
df_num = (std1**2 / n1 + std2**2 / n2)**2
df_denom = ((std1**2 / n1)**2 / (n1 - 1)) + ((std2**2 / n2)**2 / (n2 - 1))
df = df_num / df_denom

# One-tailed test (testing if Group A > Group B)
p_value = 1 - stats.t.cdf(t_stat, df)

# Output results
print(f"T-Statistic: {t_stat:.4f}")
print(f"Degrees of Freedom: {df:.2f}")
print(f"P-Value: {p_value:.4f}")

# Interpretation
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: The new training program significantly improved batting averages.")
else:
    print("Fail to reject the null hypothesis: No significant improvement detected.")
# Out:
# T-Statistic: 1.3081
# Degrees of Freedom: 52.76
# P-Value: 0.0983
# Fail to reject the null hypothesis: No significant improvement detected.
